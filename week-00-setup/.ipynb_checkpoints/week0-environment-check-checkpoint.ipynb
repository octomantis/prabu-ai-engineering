# %%
import sys
import platform

print ("Python version:", sys.version)
print ("Python executable:", sys.executable)
print ("Platform:", platform.platform())
# Out:
# Python version: 3.13.15 (v3.13.15:4061bc4c35f, Aug  5 2026, 09:08:51) [Clang 21.0.0 (clang-2100.1.1.101)]
# Python executable: /Users/praburuben/Library/CloudStorage/OneDrive-Personal/Prabu-Applied AI Engineering/prabu-ai-engineering/.venv/bin/python
# Platform: macOS-26.6.2-arm64-arm-64bit-Mach-O

# %%
import json

profile = {
    "programme": "Applied AI Engineering",
    "week": 0,
    "environment": "Prabu AI Engineering",
    "status": "working"
}

print (json.dumps(profile, indent=2))
# Out:
# {
#   "programme": "Applied AI Engineering",
#   "week": 0,
#   "environment": "Prabu AI Engineering",
#   "status": "working"
# }

# %%
import requests

response = requests.get("http://api.github.com")

print ("Status code:", response.status.code)
print ("Content type:", response.headers.get("content-type"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 5
#       1 import requests
#       2
#       3 response = requests.get("http://api.github.com")
#       4
# ----> 5 print ("Status code:", response.status.code)
#       6 print ("Content type:", response.headers.get("content-type"))
#
# AttributeError: 'Response' object has no attribute 'status'

# %%
import requests

response = requests.get("http://api.github.com")

print ("Status code:", response.status_code)
print ("Content type:", response.headers.get("content-type"))
# Out:
# Status code: 200
# Content type: application/json; charset=utf-8

# %%
data = response.json()

for key in list(data.keys())[:10]:
    print(key, ":", data[key])
# Out:
# current_user_url : https://api.github.com/user
# current_user_authorizations_html_url : https://github.com/settings/connections/applications{/client_id}
# authorizations_url : https://api.github.com/authorizations
# code_search_url : https://api.github.com/search/code?q={query}{&page,per_page,sort,order}
# commit_search_url : https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}
# emails_url : https://api.github.com/user/emails
# emojis_url : https://api.github.com/emojis
# events_url : https://api.github.com/events
# feeds_url : https://api.github.com/feeds
# followers_url : https://api.github.com/user/followers

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- -----------
# anyio                     4.14.2
# appnope                   1.0.0
# argon2-cffi               25.1.0
# argon2-cffi-bindings      26.1.0
# arrow                     1.4.0
# asttokens                 3.0.2
# async-lru                 2.3.0
# attrs                     26.1.0
# babel                     2.18.0
# beautifulsoup4            4.15.0
# bleach                    6.4.0
# certifi                   2026.7.22
# cffi                      2.1.1
# charset-normalizer        3.5.1
# comm                      0.2.3
# debugpy                   1.8.21
# defusedxml                0.7.1
# executing                 2.2.1
# fastjsonschema            2.22.2
# fqdn                      1.5.1
# h11                       0.16.0
# httpcore                  1.0.9
# httpx                     0.28.1
# idna                      3.19
# ipykernel                 7.3.0
# ipython                   9.17.0
# ipython_pygments_lexers   1.1.1
# isoduration               20.11.0
# jedi                      0.20.0
# Jinja2                    3.1.6
# json5                     0.15.0
# jsonpointer               3.1.1
# jsonschema                4.26.0
# jsonschema-specifications 2025.9.1
# jupyter_builder           1.2.2
# jupyter_client            8.10.0
# jupyter_core              5.9.1
# jupyter-events            0.12.1
# jupyter-lsp               2.3.1
# jupyter_server            2.21.0
# jupyter_server_terminals  0.5.4
# jupyterlab                4.6.3
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.28.0
# lark                      1.3.1
# MarkupSafe                3.0.3
# matplotlib-inline         0.2.2
# mistune                   3.3.4
# nbclient                  0.11.0
# nbconvert                 7.17.1
# nbformat                  5.11.1
# nest-asyncio2             1.7.2
# notebook_shim             0.2.4
# packaging                 26.3
# pandocfilters             1.5.1
# parso                     0.8.7
# pexpect                   4.9.0
# pip                       26.2.1
# platformdirs              4.11.5
# prometheus_client         0.26.0
# prompt_toolkit            3.0.53
# psutil                    7.2.2
# ptyprocess                0.7.0
# pure_eval                 0.2.3
# pycparser                 3.0
# Pygments                  2.21.0
# python-dateutil           2.9.0.post0
# python-json-logger        4.2.0
# PyYAML                    6.0.3
# pyzmq                     27.2.0
# referencing               0.37.0
# requests                  2.34.2
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rfc3987-syntax            1.1.0
# rpds-py                   2026.6.3
# Send2Trash                2.1.0
# six                       1.17.0
# soupsieve                 2.9.2
# stack-data                0.6.3
# terminado                 0.18.1
# tinycss2                  1.5.1
# tornado                   6.5.8
# traitlets                 5.16.1
# typing_extensions         4.16.0
# tzdata                    2026.3
# uri-template              1.3.0
# urllib3                   2.7.0
# wcwidth                   0.8.3
# webcolors                 25.10.0
# webencodings              0.6.1
# websocket-client          1.9.1
